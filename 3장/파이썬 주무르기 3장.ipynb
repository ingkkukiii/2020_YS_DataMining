# %%
from bs4 import BeautifulSoup

# %%
page = open("test.html", "r")

# %%
soup = BeautifulSoup(page, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code by PinkWink
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
#     <a href="http://www.pinkwink.kr" id="pw-link">
#      PinkWink
#     </a>
#    </p>
#    <p class="inner-text second-item">
#     Happy Data Science.
#     <a href="https://www.python.org" id="py-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     All I need is Love.
#    </b>
#   </p>
#  </body>
# </html>

# %%
list(soup.children)
# Out:
# ['html', '\n', <html>
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>
#  </html>]

# %%
html = list(soup.children)[2]

# %%
html
# Out:
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
list(html.children)
# Out:
# ['\n', <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>, '\n', <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>, '\n']

# %%
# 바디 부분을 보고싶을 때
soup.body # 130p 7번
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
# p : 문단 -> p에 걸려 있는 문자들은 문단 처리
# a : 앵커 -> a에 붙어있는 것이 링크
soup.find_all('p') # 전체 html 중에서 p로 시작하는
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>, <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>, <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>, <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find('p') # 전체 html 중에서 p로 제일 처음 시작하는
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
# 각 태그별로 속성까지 포함해서 찾고 싶을 때
soup.find_all('p', class_="outer-text")
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>, <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all(id="first")
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>]

# %%
soup.head # head 부분의 태그만 보겠다
# Out:
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>

# %%
soup.head.next_sibling # head 태그 나온 다음에 바로 뭐가 나오냐
# Out:
# '\n'

# %%
soup.head.next_sibling.next_sibling # head 태그 나온 다음에 바로 뭐가 나오냐, 그 다음 또 뭐가 나오냐
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
soup.body.get_text()
# Out:
# '\n\n\n                Happy PinkWink.\n                PinkWink\n\n\n                Happy Data Science.\n                Python\n\n\n\n\n                Data Science is funny.\n            \n\n\n\n                All I need is Love.\n            \n\n'

# %%
links = soup.find_all("a")
links
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>,
#  <a href="https://www.python.org" id="py-link">Python</a>]

# %%
for e in links:
    print(e, type(e))
# Out:
# <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a> <class 'bs4.element.Tag'>
# <a href="https://www.python.org" id="py-link">Python</a> <class 'bs4.element.Tag'>

# %%
for each in links:
    href = each['href']
    text = each.string
    print(text, "->", href)
# Out:
# PinkWink -> http://www.pinkwink.kr
# Python -> https://www.python.org

# %%
# 138p
from urllib.request import urlopen

# %%
url = "https://finance.naver.com/marketindex/"
page = urlopen(url)

soup = BeautifulSoup(page, "html.parser")
print(soup.prettify())
# Out:
# <script language="javascript" src="/template/head_js.nhn?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20210325123932/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20210325123932/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        환전 고시 환율
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
#         <h3 class="h_lst">
# ...

# %%
soup.find_all('span', 'value') # 태그이름이 span, 클래스가 value
# Out:
# [<span class="value">1,135.00</span>,
#  <span class="value">1,028.22</span>,
#  <span class="value">1,331.41</span>,
#  <span class="value">172.57</span>,
#  <span class="value">109.7600</span>,
#  <span class="value">1.1766</span>,
#  <span class="value">1.3774</span>,
#  <span class="value">92.9500</span>,
#  <span class="value">61.56</span>,
#  <span class="value">1534.03</span>,
#  <span class="value">1712.2</span>,
#  <span class="value">61930.2</span>]

# %%
soup.find_all('span', 'value')[0]
# Out:
# <span class="value">1,135.00</span>

# %%
soup.find_all('span', 'value')[0].string
# Out:
# '1,135.00'

# %%
for s in soup.find_all('span', 'value'):
    print(s.string)
# Out:
# 1,135.00
# 1,028.22
# 1,331.41
# 172.57
# 109.7600
# 1.1766
# 1.3774
# 92.9500
# 61.56
# 1534.03
# 1712.2
# 61930.2

# %% [markdown]
# https://www.chicagomag.com/chicago-magazine/november-2012/best-sandwiches-chicago/

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

url = 'https://www.chicagomag.com/chicago-magazine/november-2012/best-sandwiches-chicago/'

html = urlopen(url)
soup= BeautifulSoup(html, "html.parser")

soup
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-30-3484c059fd21> in <module>()
#       4 url = 'https://www.chicagomag.com/chicago-magazine/november-2012/best-sandwiches-chicago/'
#       5
# ----> 6 html = urlopen(url)
#       7 soup= BeautifulSoup(html, "html.parser")
#       8
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
# ...

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

url = 'https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=20210329'
# ? 뒤 매개변수 
html = urlopen(url)
soup= BeautifulSoup(html, "html.parser")

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&amp;date=20210329" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all('div', 'tit5')
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=196843" title="극장판 바이올렛 에버가든">극장판 바이올렛 에버가든</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=197647" title="가나의 혼인잔치: 언약">가나의 혼인잔치: 언약</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=31796" title="반지의 제왕: 왕의 귀환">반지의 제왕: 왕의 귀환</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=134899" title="동주">동주</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=31795" title="반지의 제왕: 두 개의 탑">반지의 제왕: 두 개의 탑</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=194334" title="부활: 그 증거">부활: 그 증거</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=196051" title="극장판 귀멸의 칼날: 무한열차편">극장판 귀멸의 칼날: 무한열차편</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=184517" title="소울">소울</a>
#  </div>, <div class="tit5">
# ...

# %%
soup.find_all('div', 'tit5')[0]
# Out:
# <div class="tit5">
# <a href="/movie/bi/mi/basic.nhn?code=196843" title="극장판 바이올렛 에버가든">극장판 바이올렛 에버가든</a>
# </div>

# %%
soup.find_all('div', 'tit5')[0].a.string
# Out:
# '극장판 바이올렛 에버가든'

# %%
soup.find_all('td', 'point')[0].string
# Out:
# '9.48'

# %%
import pandas as pd
import numpy as np

# %%
date = pd.date_range('2021-3-10', periods=100, freq='D')

date
# Out:
# DatetimeIndex(['2020-11-01', '2020-11-02', '2020-11-03', '2020-11-04',
#                '2020-11-05', '2020-11-06', '2020-11-07', '2020-11-08',
#                '2020-11-09', '2020-11-10', '2020-11-11', '2020-11-12',
#                '2020-11-13', '2020-11-14', '2020-11-15', '2020-11-16',
#                '2020-11-17', '2020-11-18', '2020-11-19', '2020-11-20',
#                '2020-11-21', '2020-11-22', '2020-11-23', '2020-11-24',
#                '2020-11-25', '2020-11-26', '2020-11-27', '2020-11-28',
#                '2020-11-29', '2020-11-30', '2020-12-01', '2020-12-02',
#                '2020-12-03', '2020-12-04', '2020-12-05', '2020-12-06',
#                '2020-12-07', '2020-12-08', '2020-12-09', '2020-12-10',
#                '2020-12-11', '2020-12-12', '2020-12-13', '2020-12-14',
#                '2020-12-15', '2020-12-16', '2020-12-17', '2020-12-18',
#                '2020-12-19', '2020-12-20', '2020-12-21', '2020-12-22',
# ...

# %% [markdown]
# conda install -c conda-forg tqdm

# %%
import urllib
from tqdm import tqdm_notebook

movie_date = []
movie_name = []
movie_point = []

for today in tqdm_notebook(date):
    html = "https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date={date}"
    response = urlopen(html.format(date=urllib.parse.quote(today.strftime("%Y%m%d"))))
    soup = BeautifulSoup(response, "html.parser")
    end = len(soup.find_all('td', 'point'))
    
    movie_date.extend([today for n in range(0, end)])
    movie_name.extend([soup.find_all('div', 'tit5')[n].a.string for n in range(0, end)])
    movie_point.extend([soup.find_all('td', 'point')[n].string for n in range(0, end)])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
a = [1,2,3]
b = [i*2 for i in a]
b
# 리스트 컴프리헨션 (List comprehension)
# Out:
# [2, 4, 6]

# %%
movie = pd.DataFrame({'date':movie_date, 'name':movie_name, 'point':movie_point})
movie.head()
# Out:
#         date                       name point
# 0 2020-11-01                   부활: 그 증거  9.59
# 1 2020-11-01                   포드 V 페라리  9.49
# 2 2020-11-01                    소년시절의 너  9.40
# 3 2020-11-01  그대, 고맙소 : 김호중 생애 첫 팬미팅 무비  9.39
# 4 2020-11-01                   미안해요, 리키  9.33
